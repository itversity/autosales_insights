# %%
import pandas as pd

# Create a custom DataFrame
custom_data = [
    {"sale_id": 1, "sale_rep_id": 101, "sale_date": "2024-01-01", "car_model": "Camry", "sale_amount": 20000, "priority": "High", "sale_status": "Completed"},
    {"sale_id": 2, "sale_rep_id": 102, "sale_date": "2024-01-02", "car_model": "Corolla", "sale_amount": 18000, "priority": "Medium", "sale_status": "Completed"},
    {"sale_id": 3, "sale_rep_id": 103, "sale_date": "2024-01-03", "car_model": "RAV4", "sale_amount": 30000, "priority": "High", "sale_status": "Completed"},
    {"sale_id": 2, "sale_rep_id": 102, "sale_date": "2024-01-02", "car_model": "Corolla", "sale_amount": 18000, "priority": "Medium", "sale_status": "Completed"},  # Duplicate
    {"sale_id": 4, "sale_rep_id": 104, "sale_date": "2024-01-04", "car_model": "Highlander", "sale_amount": 35000, "priority": "Low", "sale_status": "Pending"},
]

custom_df = pd.DataFrame(custom_data)

# %%
custom_data
# Out:
# [{'sale_id': 1,
#   'sale_rep_id': 101,
#   'sale_date': '2024-01-01',
#   'car_model': 'Camry',
#   'sale_amount': 20000,
#   'priority': 'High',
#   'sale_status': 'Completed'},
#  {'sale_id': 2,
#   'sale_rep_id': 102,
#   'sale_date': '2024-01-02',
#   'car_model': 'Corolla',
#   'sale_amount': 18000,
#   'priority': 'Medium',
#   'sale_status': 'Completed'},
#  {'sale_id': 3,
#   'sale_rep_id': 103,
#   'sale_date': '2024-01-03',
#   'car_model': 'RAV4',
#   'sale_amount': 30000,
#   'priority': 'High',
#   'sale_status': 'Completed'},
#  {'sale_id': 2,
#   'sale_rep_id': 102,
#   'sale_date': '2024-01-02',
#   'car_model': 'Corolla',
#   'sale_amount': 18000,
#   'priority': 'Medium',
#   'sale_status': 'Completed'},
#  {'sale_id': 4,
#   'sale_rep_id': 104,
#   'sale_date': '2024-01-04',
#   'car_model': 'Highlander',
#   'sale_amount': 35000,
#   'priority': 'Low',
#   'sale_status': 'Pending'}]

# %%
deduplicated_df = custom_df.drop_duplicates(subset=["sale_id"])

# %%
custom_df
# Out:
#    sale_id  sale_rep_id   sale_date   car_model  sale_amount priority  \
# 0        1          101  2024-01-01       Camry        20000     High
# 1        2          102  2024-01-02     Corolla        18000   Medium
# 2        3          103  2024-01-03        RAV4        30000     High
# 3        2          102  2024-01-02     Corolla        18000   Medium
# 4        4          104  2024-01-04  Highlander        35000      Low
#
#   sale_status
# 0   Completed
# 1   Completed
# 2   Completed
# 3   Completed
# 4     Pending

# %%
deduplicated_df
# Out:
#    sale_id  sale_rep_id   sale_date   car_model  sale_amount priority  \
# 0        1          101  2024-01-01       Camry        20000     High
# 1        2          102  2024-01-02     Corolla        18000   Medium
# 2        3          103  2024-01-03        RAV4        30000     High
# 4        4          104  2024-01-04  Highlander        35000      Low
#
#   sale_status
# 0   Completed
# 1   Completed
# 2   Completed
# 4     Pending

# %%
custom_df.sort_values(by="priority")
# Out:
#    sale_id  sale_rep_id   sale_date   car_model  sale_amount priority  \
# 0        1          101  2024-01-01       Camry        20000     High
# 2        3          103  2024-01-03        RAV4        30000     High
# 4        4          104  2024-01-04  Highlander        35000      Low
# 1        2          102  2024-01-02     Corolla        18000   Medium
# 3        2          102  2024-01-02     Corolla        18000   Medium
#
#   sale_status
# 0   Completed
# 2   Completed
# 4     Pending
# 1   Completed
# 3   Completed

# %%
priority_order = pd.CategoricalDtype(categories=["High", "Medium", "Low"])

# %%
custom_df["priority"] = custom_df["priority"].astype(priority_order)

# %%
custom_df.dtypes
# Out:
# sale_id           int64
# sale_rep_id       int64
# sale_date        object
# car_model        object
# sale_amount       int64
# priority       category
# sale_status      object
# dtype: object

# %%
custom_df.sort_values(by="priority")
# Out:
#    sale_id  sale_rep_id   sale_date   car_model  sale_amount priority  \
# 0        1          101  2024-01-01       Camry        20000     High
# 2        3          103  2024-01-03        RAV4        30000     High
# 1        2          102  2024-01-02     Corolla        18000   Medium
# 3        2          102  2024-01-02     Corolla        18000   Medium
# 4        4          104  2024-01-04  Highlander        35000      Low
#
#   sale_status
# 0   Completed
# 2   Completed
# 1   Completed
# 3   Completed
# 4     Pending
