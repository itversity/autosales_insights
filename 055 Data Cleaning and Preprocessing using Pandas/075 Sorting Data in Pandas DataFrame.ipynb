# %%
import pandas as pd

# Load the Toyota sales dataset
toyota_data = pd.read_csv("data/car_sales/toyota_sales_data.csv")

# %%
toyota_data["sale_date"] = pd.to_datetime(toyota_data["sale_date"])

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id  sale_date car_model  sale_amount  commission_pct  \
# 0           1           16 2024-11-18    Tundra     44496.88            0.05
# 1           2           11 2024-11-08    Tacoma     34824.72             NaN
# 2           3            5 2024-11-03   Corolla     20275.08             NaN
# 3           4           20 2024-11-06   Corolla     20068.93             NaN
# 4           5            1 2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...        ...       ...          ...             ...
# 4995     4996            1 2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8 2024-11-11     Camry     26519.24            0.05
# 4997     4998           18 2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10 2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13 2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# 0      Completed
# ...

# %%
sorted_by_amount = toyota_data.sort_values(by="sale_amount")

# %%
sorted_by_amount
# Out:
#       sale_id  sale_rep_id  sale_date car_model  sale_amount  commission_pct  \
# 2275     2276           12 2024-11-08   Corolla     20000.94            0.05
# 2464     2465           16 2024-11-02   Corolla     20001.20            0.05
# 2488     2489           16 2024-11-27   Corolla     20001.37            0.02
# 2871     2872            2 2024-11-16   Corolla     20003.27            0.05
# 4910     4911            6 2024-11-23   Corolla     20004.62            0.03
# ...       ...          ...        ...       ...          ...             ...
# 2577     2578            7 2024-11-18    Tundra     49923.84            0.02
# 3934     3935            6 2024-11-27    Tundra     49942.26            0.05
# 1901     1902            3 2024-11-12    Tundra     49974.88            0.02
# 685       686            8 2024-11-17    Tundra     49979.12            0.02
# 2877     2878           15 2024-11-02    Tundra     49995.68             NaN
#
#      sale_status
# 2275     Pending
# ...

# %%
sorted_by_amount_desc = toyota_data.sort_values(by="sale_amount", ascending=False)

# %%
sorted_by_amount_desc
# Out:
#       sale_id  sale_rep_id  sale_date car_model  sale_amount  commission_pct  \
# 2877     2878           15 2024-11-02    Tundra     49995.68             NaN
# 685       686            8 2024-11-17    Tundra     49979.12            0.02
# 1901     1902            3 2024-11-12    Tundra     49974.88            0.02
# 3934     3935            6 2024-11-27    Tundra     49942.26            0.05
# 2577     2578            7 2024-11-18    Tundra     49923.84            0.02
# ...       ...          ...        ...       ...          ...             ...
# 4910     4911            6 2024-11-23   Corolla     20004.62            0.03
# 2871     2872            2 2024-11-16   Corolla     20003.27            0.05
# 2488     2489           16 2024-11-27   Corolla     20001.37            0.02
# 2464     2465           16 2024-11-02   Corolla     20001.20            0.05
# 2275     2276           12 2024-11-08   Corolla     20000.94            0.05
#
#      sale_status
# 2877     Pending
# ...

# %%
sorted_by_status_date = toyota_data.sort_values(by=["sale_date", "sale_status"])

# %%
sorted_by_status_date
# Out:
#       sale_id  sale_rep_id  sale_date   car_model  sale_amount  \
# 26         27            7 2024-11-01      Tacoma     30218.18
# 263       264            2 2024-11-01        RAV4     30908.43
# 995       996           13 2024-11-01     Corolla     21044.21
# 2169     2170            9 2024-11-01      Tundra     39923.78
# 2214     2215            9 2024-11-01      Tundra     35228.92
# ...       ...          ...        ...         ...          ...
# 4625     4626            7 2024-11-30        RAV4     28431.57
# 4636     4637           19 2024-11-30  Highlander     35042.28
# 4708     4709           18 2024-11-30        RAV4     32612.70
# 4735     4736           11 2024-11-30        RAV4     31519.06
# 4748     4749           10 2024-11-30      Tacoma     36242.95
#
#       commission_pct sale_status
# 26              0.03   Cancelled
# 263             0.03   Cancelled
# 995             0.03   Cancelled
# 2169            0.03   Cancelled
# 2214             NaN   Cancelled
# ...

# %%
toyota_data[toyota_data["sale_status"] == "Completed"]. \
    sort_values(by="sale_date", ascending=False)
# Out:
#       sale_id  sale_rep_id  sale_date car_model  sale_amount  commission_pct  \
# 3204     3205            4 2024-11-30    Tundra     39733.80            0.03
# 3076     3077           14 2024-11-30      RAV4     33632.71            0.03
# 3248     3249            1 2024-11-30      RAV4     29887.44            0.02
# 3233     3234           17 2024-11-30      RAV4     27260.43            0.03
# 3219     3220           16 2024-11-30     Camry     25225.16            0.05
# ...       ...          ...        ...       ...          ...             ...
# 1139     1140           11 2024-11-01      RAV4     34596.69             NaN
# 1140     1141            8 2024-11-01    Tacoma     39741.88            0.03
# 2164     2165            2 2024-11-01   Corolla     24814.51             NaN
# 2162     2163           12 2024-11-01    Tacoma     38937.54            0.03
# 348       349           17 2024-11-01    Tundra     41372.43            0.02
#
#      sale_status
# 3204   Completed
# ...
