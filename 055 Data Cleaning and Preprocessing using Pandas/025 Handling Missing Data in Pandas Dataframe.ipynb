# %%
import pandas as pd

# Load the Toyota sales dataset
toyota_data = pd.read_csv("data/car_sales/toyota_sales_data.csv")

# %%
toyota_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status
# 0   Completed
# 1     Pending
# 2   Completed
# 3   Completed
# 4   Completed

# %%
toyota_data.isnull().sum()
# Out:
# sale_id              0
# sale_rep_id          0
# sale_date            0
# car_model            0
# sale_amount          0
# commission_pct    1274
# sale_status          0
# dtype: int64

# %%
toyota_data.shape
# Out:
# (5000, 7)

# %%
toyota_data["commission_pct"] = toyota_data["commission_pct"].fillna(0)

# %%
toyota_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72            0.00
# 2        3            5  2024-11-03   Corolla     20275.08            0.00
# 3        4           20  2024-11-06   Corolla     20068.93            0.00
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status
# 0   Completed
# 1     Pending
# 2   Completed
# 3   Completed
# 4   Completed

# %%
toyota_data.isnull().sum()
# Out:
# sale_id           0
# sale_rep_id       0
# sale_date         0
# car_model         0
# sale_amount       0
# commission_pct    0
# sale_status       0
# dtype: int64

# %%
toyota_data = pd.read_csv("data/car_sales/toyota_sales_data.csv")

# %%
toyota_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status
# 0   Completed
# 1     Pending
# 2   Completed
# 3   Completed
# 4   Completed

# %%
toyota_data = toyota_data.dropna(subset=["commission_pct"])

# %%
toyota_data.shape
# Out:
# (3726, 7)

# %%
toyota_data = pd.read_csv("data/car_sales/toyota_sales_data.csv")

# %%
median_commission = toyota_data["commission_pct"].median()

# %%
median_commission
# Out:
# np.float64(0.03)

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...

# %%
toyota_data["commission_pct"] = toyota_data["commission_pct"].fillna(median_commission)

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72            0.03
# 2           3            5  2024-11-03   Corolla     20275.08            0.03
# 3           4           20  2024-11-06   Corolla     20068.93            0.03
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59            0.03
# 4999     5000           13  2024-11-21    Tundra     44525.85            0.03
#
#      sale_status
# ...
