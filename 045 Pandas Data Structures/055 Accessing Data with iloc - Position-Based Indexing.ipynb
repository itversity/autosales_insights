# %%
import pandas as pd

# Load the Toyota sales and Sales Representatives datasets
toyota_data = pd.read_csv("data/car_sales/toyota_sales_data.csv")
sales_reps_data = pd.read_csv("data/car_sales/sales_reps_data.csv")

# %%
toyota_data.iloc[0:5, 0:3]
# Out:
#    sale_id  sale_rep_id   sale_date
# 0        1           16  2024-11-18
# 1        2           11  2024-11-08
# 2        3            5  2024-11-03
# 3        4           20  2024-11-06
# 4        5            1  2024-11-26

# %%
toyota_data.iloc[1, 0:3]
# Out:
# sale_id                 2
# sale_rep_id            11
# sale_date      2024-11-08
# Name: 1, dtype: object

# %%
toyota_data.iloc[1, 1]
# Out:
# np.int64(11)

# %%
toyota_data.iloc[:, 0]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: sale_id, Length: 5000, dtype: int64

# %%
sales_reps_data.iloc[2:7, 1:4]
# Out:
#     first_name last_name                         email
# 2         Paul     Jones         paul.jones@toyota.com
# 3       Robert     Lopez       robert.lopez@toyota.com
# 4       Steven    Wilson      steven.wilson@toyota.com
# 5        Brian  Martinez     brian.martinez@toyota.com
# 6  Christopher     Jones  christopher.jones@toyota.com

# %%
high_sales = toyota_data[toyota_data['sale_amount'] > 30000]

# %%
high_sales[:3]
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status
# 0   Completed
# 1     Pending
# 4   Completed

# %%
toyota_data.iloc[2, 1] = 6

# %%
toyota_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            6  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...
