# %%
import pandas as pd

# %%
sales_reps_data = pd.read_csv("data/car_sales/sales_reps_data.csv")

# %%
type(sales_reps_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sales_reps_data.head()
# Out:
#    rep_id first_name last_name                     email  phone_number  \
# 0       1    Anthony     Davis  anthony.davis@toyota.com         -5390
# 1       2     Edward     Smith   edward.smith@toyota.com        -10708
# 2       3       Paul     Jones     paul.jones@toyota.com         -2301
# 3       4     Robert     Lopez   robert.lopez@toyota.com         -8631
# 4       5     Steven    Wilson  steven.wilson@toyota.com         -6958
#
#   hire_date region  status
# 0   7/21/22  North  Active
# 1  12/24/19  North  Active
# 2    9/6/22   East  Active
# 3  11/21/20  South  Active
# 4   3/17/22   West  Active

# %%
sales_reps_data.shape[1]
# Out:
# 8

# %%
sales_reps_data.columns
# Out:
# Index(['rep_id', 'first_name', 'last_name', 'email', 'phone_number',
#        'hire_date', 'region', 'status'],
#       dtype='object')

# %%
sales_reps_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rep_id        22 non-null     int64
#  1   first_name    22 non-null     object
#  2   last_name     22 non-null     object
#  3   email         22 non-null     object
#  4   phone_number  22 non-null     int64
#  5   hire_date     22 non-null     object
#  6   region        22 non-null     object
#  7   status        22 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.5+ KB

# %%
sales_reps_data["region"]
# Out:
# 0       North
# 1       North
# 2        East
# 3       South
# 4        West
# 5        East
# 6       North
# 7       North
# 8        West
# 9       North
# 10      North
# 11       West
# 12      North
# 13      South
# 14      North
# 15       East
# 16       West
# 17      North
# 18       East
# 19      North
# 20    Unknown
# 21    Unknown
# Name: region, dtype: object

# %%
sales_reps_data[["rep_id", "region"]]
# Out:
#     rep_id   region
# 0        1    North
# 1        2    North
# 2        3     East
# 3        4    South
# 4        5     West
# 5        6     East
# 6        7    North
# 7        8    North
# 8        9     West
# 9       10    North
# 10      11    North
# 11      12     West
# 12      13    North
# 13      14    South
# 14      15    North
# 15      16     East
# 16      17     West
# 17      18    North
# 18      19     East
# 19      20    North
# 20      21  Unknown
# 21      22  Unknown

# %%
sales_reps_data.dtypes
# Out:
# rep_id           int64
# first_name      object
# last_name       object
# email           object
# phone_number     int64
# hire_date       object
# region          object
# status          object
# dtype: object

# %%
sales_reps_data.describe()
# Out:
#           rep_id  phone_number
# count  22.000000     22.000000
# mean   11.500000  -6569.909091
# std     6.493587   3083.091382
# min     1.000000 -10733.000000
# 25%     6.250000  -9525.750000
# 50%    11.500000  -6520.500000
# 75%    16.750000  -4332.250000
# max    22.000000  -1890.000000

# %%
sales_reps_data.isnull().sum()
# Out:
# rep_id          0
# first_name      0
# last_name       0
# email           0
# phone_number    0
# hire_date       0
# region          0
# status          0
# dtype: int64

# %%
toyota_sales_data = pd.read_csv('data/car_sales/toyota_sales_data.csv')

# %%
toyota_sales_data.isnull().sum()
# Out:
# sale_id              0
# sale_rep_id          0
# sale_date            0
# car_model            0
# sale_amount          0
# commission_pct    1274
# sale_status          0
# dtype: int64

# %%
sales_reps_data
# Out:
#     rep_id   first_name  last_name                         email  \
# 0        1      Anthony      Davis      anthony.davis@toyota.com
# 1        2       Edward      Smith       edward.smith@toyota.com
# 2        3         Paul      Jones         paul.jones@toyota.com
# 3        4       Robert      Lopez       robert.lopez@toyota.com
# 4        5       Steven     Wilson      steven.wilson@toyota.com
# 5        6        Brian   Martinez     brian.martinez@toyota.com
# 6        7  Christopher      Jones  christopher.jones@toyota.com
# 7        8        David      Davis        david.davis@toyota.com
# 8        9       Thomas      Smith       thomas.smith@toyota.com
# 9       10  Christopher      Brown  christopher.brown@toyota.com
# 10      11        David   Gonzalez     david.gonzalez@toyota.com
# 11      12       Daniel    Jackson     daniel.jackson@toyota.com
# 12      13       Robert  Hernandez   robert.hernandez@toyota.com
# ...

# %%
sales_reps_data["full_name"] = sales_reps_data["first_name"] + " " + sales_reps_data["last_name"]

# %%
sales_reps_data
# Out:
#     rep_id   first_name  last_name                         email  \
# 0        1      Anthony      Davis      anthony.davis@toyota.com
# 1        2       Edward      Smith       edward.smith@toyota.com
# 2        3         Paul      Jones         paul.jones@toyota.com
# 3        4       Robert      Lopez       robert.lopez@toyota.com
# 4        5       Steven     Wilson      steven.wilson@toyota.com
# 5        6        Brian   Martinez     brian.martinez@toyota.com
# 6        7  Christopher      Jones  christopher.jones@toyota.com
# 7        8        David      Davis        david.davis@toyota.com
# 8        9       Thomas      Smith       thomas.smith@toyota.com
# 9       10  Christopher      Brown  christopher.brown@toyota.com
# 10      11        David   Gonzalez     david.gonzalez@toyota.com
# 11      12       Daniel    Jackson     daniel.jackson@toyota.com
# 12      13       Robert  Hernandez   robert.hernandez@toyota.com
# ...

# %%
help(sales_reps_data.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(
#     labels: 'IndexLabel | None' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | None' = None,
#     columns: 'IndexLabel | None' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise'
# ) -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
# ...

# %%
sales_reps_data.columns
# Out:
# Index(['rep_id', 'first_name', 'last_name', 'email', 'phone_number',
#        'hire_date', 'region', 'status', 'full_name'],
#       dtype='object')

# %%
sales_reps_data.drop(["first_name", "last_name"], axis=1)
# Out:
#     rep_id                         email  phone_number hire_date   region  \
# 0        1      anthony.davis@toyota.com         -5390   7/21/22    North
# 1        2       edward.smith@toyota.com        -10708  12/24/19    North
# 2        3         paul.jones@toyota.com         -2301    9/6/22     East
# 3        4       robert.lopez@toyota.com         -8631  11/21/20    South
# 4        5      steven.wilson@toyota.com         -6958   3/17/22     West
# 5        6     brian.martinez@toyota.com         -8376   6/25/23     East
# 6        7  christopher.jones@toyota.com         -1890   2/28/21    North
# 7        8        david.davis@toyota.com         -6153   8/29/21    North
# 8        9       thomas.smith@toyota.com         -2623    4/2/22     West
# 9       10  christopher.brown@toyota.com        -10635   8/15/20    North
# 10      11     david.gonzalez@toyota.com         -3340  11/11/20    North
# 11      12     daniel.jackson@toyota.com        -10733   8/22/22     West
# ...
