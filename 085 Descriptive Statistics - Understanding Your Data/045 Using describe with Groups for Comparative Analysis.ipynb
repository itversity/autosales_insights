# %%
import pandas as pd

# %%
toyota_sales = pd.read_csv("data/car_sales/toyota_sales_data.csv")

# %%
toyota_sales.groupby("car_model")["sale_amount"].describe()
# Out:
#             count          mean          std       min         25%        50%  \
# car_model
# Camry       856.0  27470.874825  1430.891192  25006.17  26248.2500  27448.575
# Corolla     827.0  22442.176808  1460.472207  20000.94  21123.4350  22477.280
# Highlander  814.0  40002.871658  2912.373577  35008.84  37483.4900  39988.890
# RAV4        860.0  30985.724349  2356.255894  27002.66  28964.0375  30922.640
# Tacoma      826.0  34998.464068  2906.544809  30011.69  32421.8900  34989.815
# Tundra      817.0  42478.580428  4236.084042  35026.61  38943.1100  42306.670
#
#                    75%       max
# car_model
# Camry       28679.1950  29981.84
# Corolla     23723.8150  24996.35
# Highlander  42514.5175  44975.88
# RAV4        33016.2925  34965.01
# Tacoma      37517.3625  39994.13
# Tundra      46146.2900  49995.68

# %%
sales_reps = pd.read_csv("data/car_sales/sales_reps_data.csv")

# %%
# Merge to get region info
sales_with_region = toyota_sales.merge(
    sales_reps[['rep_id', 'region']], 
    left_on='sale_rep_id', 
    right_on='rep_id'
)

# %%
sales_with_region.groupby("region")["sale_amount"].describe()
# Out:
#          count          mean          std       min        25%        50%  \
# region
# East     986.0  32984.519118  7576.315037  20001.20  27346.225  32070.810
# North   2526.0  33038.378274  7344.735779  20003.27  27347.775  32889.685
# South    479.0  32863.790209  7533.823148  20106.29  27098.520  32320.140
# West    1009.0  32883.157770  7409.716683  20000.94  27100.000  32463.620
#
#                75%       max
# region
# East    39016.1575  49974.88
# North   38713.1200  49995.68
# South   38865.9150  49907.66
# West    38627.6500  49810.29

# %%
sales_with_region.groupby("region")["sale_amount"].sum()
# Out:
# region
# East     32522735.85
# North    83454943.52
# South    15741755.51
# West     33179106.19
# Name: sale_amount, dtype: float64

# %%
toyota_sales.groupby("sale_status")["sale_amount"].describe()
# Out:
#               count          mean          std       min         25%  \
# sale_status
# Cancelled     382.0  33048.315550  7262.912029  20139.53  27600.0275
# Completed    3543.0  33389.033201  7396.169136  20001.20  27704.1650
# Pending      1075.0  31606.269674  7397.291425  20000.94  25841.9400
#
#                   50%        75%       max
# sale_status
# Cancelled    32371.09  39175.095  49974.88
# Completed    33198.04  39053.745  49979.12
# Pending      29778.34  37433.800  49995.68

# %%
toyota_sales.groupby("car_model")[["sale_amount", "commission_pct"]].describe()
# Out:
#            sale_amount                                                   \
#                  count          mean          std       min         25%
# car_model
# Camry            856.0  27470.874825  1430.891192  25006.17  26248.2500
# Corolla          827.0  22442.176808  1460.472207  20000.94  21123.4350
# Highlander       814.0  40002.871658  2912.373577  35008.84  37483.4900
# RAV4             860.0  30985.724349  2356.255894  27002.66  28964.0375
# Tacoma           826.0  34998.464068  2906.544809  30011.69  32421.8900
# Tundra           817.0  42478.580428  4236.084042  35026.61  38943.1100
#
#                                             commission_pct            \
#                   50%         75%       max          count      mean
# car_model
# Camry       27448.575  28679.1950  29981.84          612.0  0.033497
# Corolla     22477.280  23723.8150  24996.35          626.0  0.033786
# Highlander  39988.890  42514.5175  44975.88          614.0  0.034316
# ...
