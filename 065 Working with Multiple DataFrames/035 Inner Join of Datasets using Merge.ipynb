# %%
import pandas as pd

# Load the Toyota sales and sales reps dataset
toyota_sales_data = pd.read_csv("data/car_sales/toyota_sales_data.csv")
sales_reps_data = pd.read_csv("data/car_sales/sales_reps_data.csv")

# %%
merged_data = pd.merge(toyota_sales_data, 
    sales_reps_data, 
    left_on='sale_rep_id', 
    right_on='rep_id', 
    how='inner'
)
print(merged_data[[]].head())

# %%
toyota_sales_data.head(20)

# %%
sales_reps_data.head(22)

# %%
sorted(list(toyota_sales_data["sale_rep_id"].unique()))

# %%
help(pd.merge)

# %%
merged_data = pd.merge(
    toyota_sales_data,
    sales_reps_data,
    left_on="sale_rep_id",
    right_on="rep_id",
    how="inner"
)

# %%
merged_data[["sale_id", "sale_rep_id", "first_name", "last_name", "region", "sale_amount"]].head(20)

# %%
merged_data.shape

# %%
toyota_sales_data.shape

# %%
sales_reps_data.shape

# %%
merged_data["sale_rep_id"].unique()
